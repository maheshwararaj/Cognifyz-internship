# %% [markdown]
# <a href="https://colab.research.google.com/github/maheshwararaj/Cognifyz-internship/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import pandas as pd

df_all_cols = pd.read_csv('sample.csv')
print(f"Available columns in the CSV: {df_all_cols.columns.tolist()}")

df = pd.read_csv('sample.csv', usecols=df_all_cols.columns.tolist())
print(df)
marks1 = df['physics'].values.tolist()
marks_score = df['chemistry'].hist()
plt.xlabel('Physics Marks')
plt.ylabel("Frequency")
plt.show()

plt.scatter(df['physics'],df['chemistry'],alpha = 0.5,color = 'red')
plt.xlabel('Physics Marks')
plt.ylabel("Chemistry Marks")
plt.show()

df.plot.box(title="Marks box")
plt.show(block=True)

sums = df.selected.groupby(df['gender']).sum()
plt.pie(sums,labels=sums.index)
plt.show()



df.plot(kind='box',subplots=True,layout=(3,3),sharex=False,sharey=False)
plt.show()
# Out:
# Available columns in the CSV: ['id', 'name', 'gender', 'physics', 'chemistry', 'maths', 'biology', 'language', 'selected']
#    id        name  gender  physics  chemistry  maths  biology  language  \
# 0   1   Student_1    male       78         56     89       92        65
# 1   2   Student_2  female       65         72     58       84        76
# 2   3   Student_3    male       89         92     95       76        84
# 3   4   Student_4  female       67         58     74       65        88
# 4   5   Student_5    male       90         80     88       84        92
# 5   6   Student_6  female       56         67     54       80        69
# 6   7   Student_7    male       85         79     80       73        60
# 7   8   Student_8  female       72         65     81       68        77
# 8   9   Student_9    male       88         90     75       86        91
# 9  10  Student_10  female       79         82     70       74        65
#
#    selected
# 0      True
# 1     False
# 2      True
# ...

# %%
import numpy as np
from sklearn import decomposition

x = np.array([[2,1,3],[6,7,5],[2,3,1]])

pca = decomposition.PCA(n_components = 3)
x_pca = pca.fit_transform(x)
print(x_pca)

inver = pca.inverse_transform(x_pca)
print(inver)
print(pca.explained_variance_ratio_)
print(pca.singular_values_)
# Out:
# [[-2.67553361e+00  1.31545003e+00  1.79512423e-17]
#  [ 4.71240146e+00  1.24477608e-01  1.79512423e-17]
#  [-2.03686785e+00 -1.43992763e+00  1.79512423e-17]]
# [[2. 1. 3.]
#  [6. 7. 5.]
#  [2. 3. 1.]]
# [8.97697454e-01 1.02302546e-01 2.58948564e-35]
# [5.78913105e+00 1.95430167e+00 3.10924638e-17]

# %%
import numpy as np
from numpy.linalg import eig
from sklearn import decomposition

X = np.array([[3,6],[4,7]])

M = np.mean(X.T,axis=1)

C = X-M
print(C)

V = np.cov(C.T)
print(V)

values,vectors = eig(V)
print(values,vectors)
# Out:
# [[-0.5 -0.5]
#  [ 0.5  0.5]]
# [[0.5 0.5]
#  [0.5 0.5]]
# [1.00000000e+00 1.11022302e-16] [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]

# %%
import csv
attr_values = [['g9','g8'],['Yes','No'],['Excellent','Good'],['Good','Bad'], ['Fast','Slow'],['Yes','No']]
n_att = len(attr_values)

h = ['0'] * n_att
a = []
print(h)
with open('sample1.csv','r') as csvfile:
  reader = csv.reader(csvfile)

  for row in reader:

    a.append(row)
  print(a)

  for j in range (0,n_att) :
    h[j] = a[1][j]
  print("H \n")
  print(h)


  for i in range(1,len(a)):
    if a[i][n_att]=='Yes':
            for j in range(0,n_att):
                if a[i][j]!=h[j]:
                    h[j]='?'
                else :
                    h[j]= a[i][j]
    print(" Training Instance :{0} the hypothesis 'h' is ".format(i),h)
  print("\n The Final Maximally Specific Hypothesis 'h' is  :\n")
  print(h)
# Out:
# ['0', '0', '0', '0', '0', '0']
# [['CGPA', 'Interactiveness', 'Practical Knowledge', 'Communication Skills', 'Logical Thinking', 'Interest', 'Job Offer'], ['>=9', 'Yes', 'Excellent', 'Good', 'Fast', 'Yes', 'Yes'], ['>=9', 'Yes', 'Good', 'Good', 'Fast', 'Yes', 'Yes'], ['>=8', 'No', 'Good', 'Good', 'Fast', 'No', 'No'], ['>=9', 'Yes', 'Good', 'Good', 'Slow', 'No', 'Yes']]
# H
#
# ['>=9', 'Yes', 'Excellent', 'Good', 'Fast', 'Yes']
#  Training Instance :1 the hypothesis 'h' is  ['>=9', 'Yes', 'Excellent', 'Good', 'Fast', 'Yes']
#  Training Instance :2 the hypothesis 'h' is  ['>=9', 'Yes', '?', 'Good', 'Fast', 'Yes']
#  Training Instance :3 the hypothesis 'h' is  ['>=9', 'Yes', '?', 'Good', 'Fast', 'Yes']
#  Training Instance :4 the hypothesis 'h' is  ['>=9', 'Yes', '?', 'Good', '?', '?']
#
#  The Final Maximally Specific Hypothesis 'h' is  :
#
# ['>=9', 'Yes', '?', 'Good', '?', '?']
